# %% [markdown]
# <a href="https://colab.research.google.com/github/micahdrobbins/INFO450/blob/main/lesson3/Day3_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to APIs

# %%
import requests

# %%
response=requests.get("https://catfact.ninja/fact")

# %%
response.json()
# Out:
# {'fact': 'There is a species of cat smaller than the average housecat. It is native to Africa and it is the Black-footed cat (Felis nigripes). Its top weight is 5.5 pounds.',
#  'length': 162}

# %%
data=response.json()
type(data)
# Out:
# dict

# %%
data['fact']
# Out:
# 'There is a species of cat smaller than the average housecat. It is native to Africa and it is the Black-footed cat (Felis nigripes). Its top weight is 5.5 pounds.'

# %% [markdown]
# # World API

# %%
#This is going to pull data from world cup API
url = "https://raw.githubusercontent.com/openfootball/worldcup.json/master/2026/worldcup.json"
response=requests.get(url)

# %%
response
data=response.json()
data.keys()
data['matches']
first_match=data['matches'][0]
five_five_match=data['matches'][55]
five_five_match['score']['ft'][0]
# Out:
# 3

# %% [markdown]
# Using my github as an API

# %%
import requests
url = "https://raw.githubusercontent.com/micahdrobbins/INFO450/main/parts.json"
response=requests.get(url)
data=response.json()
data['parts'][1]['name']
# Out:
# 'Motherboard'

# %% [markdown]
# Weather API

# %%
import requests

# API endpoint for historical weather
url = "https://historical-forecast-api.open-meteo.com/v1/forecast"

# Parameters for the request
params = {
"latitude": 40.7128, # Latitude for New York City
"longitude": -74.0060, # Longitude for New York City
"start_date": "2025-06-20", # Start date for the past week
"end_date": "2025-06-26", # End date for the past week
"daily": "temperature_2m_max", # Daily maximum temperature
"timezone": "auto" # Automatically adjust for timezone
}

# Fetch data from the API
response = requests.get(url, params=params)
data = response.json()

# %%
temperatures=data["daily"]['temperature_2m_max']

# %%
temperatures
# Out:
# [29.5, 31.8, 32.4, 36.0, 39.1, 38.2, 30.7]

# %%
del(min)

# %%
min(temperatures)
# Out:
# 29.5

# %%
sum(temperatures)/len(temperatures)
# Out:
# 33.957142857142856
